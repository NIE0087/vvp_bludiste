# %% [markdown]
# Import funkcí a knihoven

# %%
from maze_project import Maze
import numpy as np

# %% [markdown]
# Vytvoření instance

# %%
maze_solver = Maze()

# %% [markdown]
# Načtení bludišť ze souboru

# %%
mazes, number_of_mazes = maze_solver.load_mazes()

# %% [markdown]
# Přetypování matic typu bool na typ int

# %%
incidence_matrices = maze_solver.construct_incidence_matrix()

# %% [markdown]
# Zavolání funkce pro nalezení cesty v načtených bludištích

# %%
paths_in_mazes = []
for i in range(number_of_mazes-1):
    paths_in_mazes.append(maze_solver.bfs_shortest_path(incidence_matrices[i]))

# %% [markdown]
# Vykreslení bludišť společně s cestami

# %%
index = 1
for i in range(number_of_mazes - 1):
    maze_solver.plot_maze_and_path(mazes[i], paths_in_mazes[i], index)
    index +=1

# %% [markdown]
# Šablony pro generování bludišť

# %%
empty = np.zeros((50,50))

slalom = np.zeros((50,50))
slalom[10][:25] = [1] * 25
slalom[35][-35:] = [1] * 35

# %%
more_barriers = np.zeros((50,50))
more_barriers[5:25, 10] = 1
more_barriers[5:25, 11] = 1
more_barriers[10:30, 18] = 1
more_barriers[10:30, 17] = 1
more_barriers[15:35, 25] = 1
more_barriers[15:35, 26] = 1
more_barriers[10:30, 33] = 1
more_barriers[10:30, 34] = 1
more_barriers[5:25, 40] = 1
more_barriers[5:25, 41] = 1

# %% [markdown]
# Vykreslení bludišť

# %%
for i in range(2):  
    
    my_maze = maze_solver.bfs_shortest_path(maze_solver.maze_generator_helper(empty))

    maze_solver.plot_maze_and_path(empty,my_maze,1)

    my_maze = maze_solver.bfs_shortest_path(maze_solver.maze_generator_helper(slalom))

    maze_solver.plot_maze_and_path(slalom,my_maze,2)

# %% [markdown]
# VŠB logo

# %%
    my_maze = maze_solver.bfs_shortest_path(maze_solver.maze_generator_helper(more_barriers))

    maze_solver.plot_maze_and_path(more_barriers,my_maze,3)

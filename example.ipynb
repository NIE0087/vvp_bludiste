# %% [markdown]
# Import funkcí a knihoven

# %%
from MazeFunctions import *

# %% [markdown]
# Načtení bludišť ze souboru

# %%
mazes, Number_of_mazes = load_mazes()

# %% [markdown]
# Přetypování matic typu bool na typ int

# %%
incidence_matrices = construct_incidence_matrix(mazes)

# %% [markdown]
# Zavolání funkce pro nalezení cesty v načtených bludištích

# %%
paths_in_mazes = []
for i in range(Number_of_mazes-1):
    paths_in_mazes.append(bfs_shortest_path(incidence_matrices[i]))

# %% [markdown]
# Vykreslení bludišť společně s cestami

# %%
index = 1
for i in range(Number_of_mazes - 1):
    plot_of_maze_and_path(incidence_matrices[i],paths_in_mazes[i],index)
    index +=1

# %% [markdown]
# Šablony pro generování bludišť

# %%
Empty = np.zeros((50,50))

Slalom = np.zeros((50,50))
Slalom[10][:25] = [1] * 25
Slalom[35][-35:] = [1] * 35

# %%
MoreBarriers = np.zeros((50,50))
MoreBarriers[5:25, 10] = 1
MoreBarriers[5:25, 11] = 1
MoreBarriers[10:30, 18] = 1
MoreBarriers[10:30, 17] = 1
MoreBarriers[15:35, 25] = 1
MoreBarriers[15:35, 26] = 1
MoreBarriers[10:30, 33] = 1
MoreBarriers[10:30, 34] = 1
MoreBarriers[5:25, 40] = 1
MoreBarriers[5:25, 41] = 1

# %% [markdown]
# Vykreslení bludišť

# %%
for i in range(2):  
    a = bfs_shortest_path(Maze_generator_helper(Empty))

    plot_of_maze_and_path(Empty,a,1)

    a = bfs_shortest_path(Maze_generator_helper(Slalom))

    plot_of_maze_and_path(Slalom,a,2)

# %% [markdown]
# VSB logo

# %%
    a = bfs_shortest_path(Maze_generator_helper(MoreBarriers))

    plot_of_maze_and_path(MoreBarriers,a,3)
